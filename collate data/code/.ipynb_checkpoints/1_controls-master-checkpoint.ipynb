# %%
import pandas as pd
import os

# %% [raw]
# """
#
#     this is to extract as many controls as possible;
#     since we have large dataset (30K LSOAs)
#     we hope that we can include as many controls as needed;
#
#     using 2021 Census in the UK;
#     first part of the notebook is where I manually extract the data
#     second part includes selected variables extracted by quering the
#     webiste: https://www.nomisweb.co.uk/sources/census_2021_ts
#     which i found later and seems to be easier to use
#
# """

# %%
data_folder1 = '../data/controls/2021/COLLECTED/'

# %% [markdown]
# # 1

# %% [markdown]
# # We merge everything in here

# %%
first_f = 'age-census2021-ts007a-lsoa.csv' 
DF = pd.read_csv(data_folder1 + first_f)
for f in os.listdir(data_folder1):
    if f.endswith('-lsoa.csv') and f != first_f:
        print(f)
        df = pd.read_csv(data_folder1 + f)
        if not 'date' in df.columns:
            df['date'] = 2021
        
        DF = DF.merge(df, on=['date', 'geography', 'geography code'])
# Out:
# maritalstatus-census2021-lsoa.csv
# hourswork-census2021-ts059-lsoa.csv
# unemployed-census2021-ts065-lsoa.csv
# religion-census2021-ts030-lsoa.csv
# sex-census2021-ts008-lsoa.csv
# deprivations_v2-lsoa.csv
# language-census2021-ts029-lsoa.csv
# disability-census2021-ts040-lsoa.csv
# distancetowork-census2021-ts058-lsoa.csv
# health-census2021-ts037-lsoa.csv
# householdtype-census2021-ts003-lsoa.csv
# methodtraveltowork-census2021-ts061-lsoa.csv
# numhouseholds-census2021-ts041-lsoa.csv

# %%
DF.head()
# Out:
#    date                  geography geography code  Age: Total  \
# 0  2021        City of London 001A      E01000001        1473
# 1  2021        City of London 001B      E01000002        1384
# 2  2021        City of London 001C      E01000003        1613
# 3  2021        City of London 001E      E01000005        1101
# 4  2021  Barking and Dagenham 016A      E01000006        1842
#
#    Age: Aged 4 years and under  Age: Aged 5 to 9 years  \
# 0                           52                      34
# 1                           33                      24
# 2                           39                      32
# 3                           52                      45
# 4                          153                     127
#
#    Age: Aged 10 to 14 years  Age: Aged 15 to 19 years  \
# 0                        32                        23
# 1                        22                        31
# 2                        33                        23
# 3                        35                        89
# 4                       110                       122
#
#    Age: Aged 20 to 24 years  Age: Aged 25 to 29 years  ...  \
# 0                        90                       159  ...
# 1                       100                       166  ...
# 2                        96                       187  ...
# 3                       118                        97  ...
# 4                       124                       130  ...
#
#    Method of travel to workplace: Train  \
# 0                                    17
# 1                                    10
# 2                                    21
# 3                                    25
# 4                                   104
#
#    Method of travel to workplace: Bus, minibus or coach  \
# 0                                                 13
# 1                                                 15
# 2                                                 26
# 3                                                 44
# 4                                                 60
#
#    Method of travel to workplace: Taxi  \
# 0                                    4
# 1                                    2
# 2                                    4
# 3                                    2
# 4                                    1
#
#    Method of travel to workplace: Motorcycle, scooter or moped  \
# 0                                                  3
# 1                                                  1
# 2                                                  4
# 3                                                  3
# 4                                                  5
#
#    Method of travel to workplace: Driving a car or van  \
# 0                                                 18
# 1                                                 19
# 2                                                 24
# 3                                                 33
# 4                                                227
#
#    Method of travel to workplace: Passenger in a car or van  \
# 0                                                  0
# 1                                                  3
# 2                                                  7
# 3                                                  1
# 4                                                 10
#
#    Method of travel to workplace: Bicycle  \
# 0                                      24
# 1                                      25
# 2                                      62
# 3                                      18
# 4                                       6
#
#    Method of travel to workplace: On foot  \
# 0                                     109
# 1                                      92
# 2                                     143
# 3                                      90
# 4                                      61
#
#    Method of travel to workplace: Other method of travel to work  \
# 0                                                  4
# 1                                                  7
# 2                                                 17
# 3                                                  8
# 4                                                 17
#
#    Number of households: Number of households; measures: Value
# 0                                                838
# 1                                                824
# 2                                               1017
# 3                                                480
# 4                                                554
#
# [5 rows x 140 columns]

# %%
len(DF)
# Out:
# 35672

# %%
DF.to_csv('../data/glavni/raw_full_controls.csv', index=None)

# %% [markdown]
# ## Age

# %%
f = 'age-census2021-ts007a-lsoa.csv' 

df = pd.read_csv(data_folder1 + f)
del df['date']
df['percent aged 65plus'] = (df['Age: Aged 65 to 69 years']+df['Age: Aged 70 to 74 years']+\
                             +df['Age: Aged 75 to 79 years']++df['Age: Aged 80 to 84 years']+\
                             df['Age: Aged 85 years and over'])/df['Age: Total']
df['percent children up to 14'] = (df['Age: Aged 4 years and under']+df['Age: Aged 5 to 9 years']+\
                             +df['Age: Aged 10 to 14 years']+\
                             df['Age: Aged 85 years and over'])/df['Age: Total']
df['total population'] = df['Age: Total']

df_rural = df[['total population', 'geography code', 'geography']]

del df['Age: Total']
# del df['Age: Aged 85 years and over']
# for c in df_age.columns:
#     if c not in ['geography',	'geography code', 'total population']:
#         df_age[c] = df_age[c]/df_age['total population']
#         df_age.rename(columns={c:c.replace("Age:", "percent")}, inplace=True)
#         df_age.rename(columns={c : c.lower()}, inplace=True)

df_age = df[['geography code', 'geography', 'percent children up to 14', 'percent aged 65plus']]
df_age = df_age.set_index(['geography',	'geography code'])
df_age.head()
# Out:
#                                           percent children up to 14  \
# geography                 geography code
# City of London 001A       E01000001                        0.103870
# City of London 001B       E01000002                        0.078757
# City of London 001C       E01000003                        0.084935
# City of London 001E       E01000005                        0.130790
# Barking and Dagenham 016A E01000006                        0.220413
#
#                                           percent aged 65plus
# geography                 geography code
# City of London 001A       E01000001                  0.251188
# City of London 001B       E01000002                  0.200145
# City of London 001C       E01000003                  0.176689
# City of London 001E       E01000005                  0.094460
# Barking and Dagenham 016A E01000006                  0.085776

# %%
# f = 'age-census2021-ts007a-lsoa.csv' 

# df = pd.read_csv(data_folder + f)
# del df['date']
# df['percent aged 65plus'] = (df['Age: Aged 65 to 69 years']+df['Age: Aged 70 to 74 years']+\
#                              +df['Age: Aged 75 to 79 years']++df['Age: Aged 80 to 84 years']+\
#                              df['Age: Aged 85 years and over'])/df['Age: Total']
# df['percent children up to 14'] = (df['Age: Aged 4 years and under']+df['Age: Aged 5 to 9 years']+\
#                              +df['Age: Aged 10 to 14 years']+\
#                              df['Age: Aged 85 years and over'])/df['Age: Total']
# df['total population'] = df['Age: Total']
# del df['Age: Total']
# df_age=df[['geography',	'geography code', 'percent aged 65plus', 'percent children up to 14', 'total population']]
# df_age = df_age.set_index(['geography',	'geography code'])
# # for c in df_age.columns:
# #     if c not in ['geography',	'geography code', 'total population']:
# #         df_age[c] = df_age[c]/df_age['total population']
# #         df_age.rename(columns={c:c.replace("Age:", "percent")}, inplace=True)
# df_age.head()

# %% [markdown]
# # Use Total Populations from df_age to extract Urban vs Rural indicator

# %%
# df_rural['urban area'] = df_rural['total population']>10000
# df_rural['urban area'] = df_rural['urban area'].astype(int)
df_rural = df_rural.set_index(['geography',	'geography code'])

# %% [markdown]
# ## Sex

# %%
f = 'sex-census2021-ts008-lsoa.csv'
df = pd.read_csv(data_folder1 + f)
del df['date']
df['percent male'] = df['Sex: Male; measures: Value']/df['Sex: All persons; measures: Value']
for c in ['Sex: All persons; measures: Value','Sex: Male; measures: Value', 'Sex: Female; measures: Value']:
    del df[c]
df_sex = df.set_index(['geography',	'geography code'])

# %% [markdown]
# ## Deprivation

# %%
f = 'deprivations_v2-lsoa.csv'
df = pd.read_csv(data_folder1 + f)
del df['data']
# df['percent non-deprived'] = df['Household is not deprived in any dimension']/df['Total: All households']
df['percent mid-deprived'] = df['Household is deprived in two dimensions']/df['Total: All households']
df['percent highly-deprived'] = df['Household is deprived in four dimensions']/df['Total: All households']

df=df[['geography',	'geography code','percent highly-deprived', 'percent mid-deprived']]
df_dep = df.set_index(['geography',	'geography code'])

# %% [markdown]
# ## Language

# %%
f = 'language-census2021-ts029-lsoa.csv'
df = pd.read_csv(data_folder1 + f)
# del df['data']
# df['percent non-english'] = df['Proficiency in English language: Main language is not English (English or Welsh in Wales)']/\
#     df['Proficiency in English language: Total: All usual residents aged 3 years and over']
df['percent poor-english'] = df['Proficiency in English language: Main language is not English (English or Welsh in Wales): Cannot speak English well']/\
     df['Proficiency in English language: Total: All usual residents aged 3 years and over']

df=df[['geography',	'geography code', 'percent poor-english']]
df_lan = df.set_index(['geography',	'geography code'])

# %% [markdown]
# ## Health

# %%
f = 'health-census2021-ts037-lsoa.csv'
df = pd.read_csv(data_folder1 + f)
del df['date']
df['percent very good health'] = df['General health: Very good health']/\
    df['General health: Total: All usual residents']
df['percent bad health'] = df['General health: Bad health']/\
    df['General health: Total: All usual residents']

df=df[['geography',	'geography code', 'percent very good health',\
       'percent bad health']]
df_health = df.set_index(['geography',	'geography code'])

# %% [markdown]
# ## Unemployment

# %%
f = 'health-census2021-ts037-lsoa.csv'
total_residents = pd.read_csv(data_folder1 + f)[['General health: Total: All usual residents', 'geography code']]
total_residents.rename(columns={'General health: Total: All usual residents':'total residents'}, inplace=True)

f = 'unemployed-census2021-ts065-lsoa.csv'
df = pd.read_csv(data_folder1 + f)
df = df.merge(total_residents, on =['geography code'])
df['percent unemployed'] = df['Unemployment history: Total: All usual residents aged 16 years and over not in employment the week before the census']/\
    df['total residents']
df=df[['geography',	'geography code', 'percent unemployed']]

df_unempl = df.set_index(['geography',	'geography code'])

# %% [markdown]
# ## Marital

# %%
# f = 'health-census2021-ts037-lsoa.csv'
# total_residents = pd.read_csv(data_folder + f)[['General health: Total: All usual residents', 'geography code']]
# total_residents.rename(columns={'General health: Total: All usual residents':'total residents'}, inplace=True)

f = 'maritalstatus-census2021-lsoa.csv'
df = pd.read_csv(data_folder1 + f)
# df = df.merge(total_residents, on =['geography code'])
df['percent married or in civil partnership'] = \
    df['Marital and civil partnership status: Married or in a registered civil partnership; measures: Value']/\
    df['Marital and civil partnership status: Total; measures: Value']
df=df[['geography',	'geography code', 'percent married or in civil partnership']]

df_married = df.set_index(['geography',	'geography code'])

# %% [markdown]
# # Join all of these

# %%
DF = df_age.join(df_married).join(df_unempl).join(df_health).\
            join(df_lan).join(df_dep).join(df_sex).join(df_rural)

# %%
DF.to_csv('../data/glavni/controls_first_group.csv')

# %% [markdown]
# # 2

# %%
import pandas as pd
import os

# %%
data_folder = '../data/controls/2021/QUERIED/'

# %% [markdown]
# ## Ethnic background

# %%
first_f = 'ethnic_background.csv' 
DF = pd.read_csv(data_folder + first_f).\
    rename(columns={'mnemonic':'geography code'})

# %%
DF['percent asian'] = DF['Asian, Asian British or Asian Welsh'] / DF['Total: All usual residents']

DF['percent black'] = DF['Black, Black British, Black Welsh, Caribbean or African'] / DF['Total: All usual residents']

DF['percent mixed'] = DF['Mixed or Multiple ethnic groups'] / DF['Total: All usual residents']

DF['percent white'] = DF['White'] / DF['Total: All usual residents']

# DF['percent other ethnic'] = DF['Other ethnic group'] / DF['Total: All usual residents']

# %%
df_ethnic = DF[['geography code', 'percent asian','percent black', 'percent mixed', 'percent white']].\
            set_index(['geography code'])

# %% [markdown]
# ## Religion

# %%
f2 = 'religion.csv' 
DF = pd.read_csv(data_folder + f2).\
    rename(columns={'mnemonic':'geography code'})

# %%
DF['percent no religion'] = DF['No religion'] / DF['Total: All usual residents']

DF['percent christian'] = DF['Christian'] / DF['Total: All usual residents']

# DF['percent buddhist'] = DF['Buddhist'] / DF['Total: All usual residents']

# DF['percent hindu'] = DF['Hindu'] / DF['Total: All usual residents']

DF['percent jewish'] = DF['Jewish'] / DF['Total: All usual residents']

DF['percent muslim'] = DF['Muslim'] / DF['Total: All usual residents']

# DF['percent sikh'] = DF['Sikh'] / DF['Total: All usual residents']

# DF['percent other religion'] = DF['Other religion'] / DF['Total: All usual residents']

# %%
df_religion=DF[['geography code', \
                'percent christian', 'percent jewish',\
                'percent no religion','percent muslim',\
               ]].set_index(['geography code'])

# %% [markdown]
# ## central heating

# %%
first_f = 'central_heating.csv' 
DF = pd.read_csv(data_folder + first_f).\
    rename(columns={'mnemonic':'geography code'})

# %%
DF.head()
# Out:
#   2021 super output area - lower layer geography code  Total: All households  \
# 0                      Hartlepool 001A      E01011954                    964
# 1                      Hartlepool 001B      E01011969                    603
# 2                      Hartlepool 001C      E01011970                    484
# 3                      Hartlepool 001D      E01011971                    518
# 4                      Hartlepool 001F      E01033465                    738
#
#    No central heating  Wood only  District or communal heat networks only
# 0                   6          0                                        3
# 1                   5          0                                        1
# 2                  10          0                                        0
# 3                   0          0                                        0
# 4                   0          0                                        0

# %%
DF['percent no central heating'] = DF['No central heating'] / DF['Total: All households']

DF['percent wood heating'] = DF['Wood only'] / DF['Total: All households']

DF['percent communal heating'] = DF['District or communal heat networks only'] / DF['Total: All households']

# %%
df_heating = DF[['geography code', 'percent no central heating','percent wood heating',\
                  'percent communal heating']].set_index(['geography code'])

# %% [markdown]
# ## distance travelled to work

# %%
first_f = 'distance_to_work.csv' 
DF = pd.read_csv(data_folder + first_f).\
    rename(columns={'mnemonic':'geography code'})

# %%
DF.head()
# Out:
#   2021 super output area - lower layer geography code  \
# 0                      Hartlepool 001A      E01011954
# 1                      Hartlepool 001B      E01011969
# 2                      Hartlepool 001C      E01011970
# 3                      Hartlepool 001D      E01011971
# 4                      Hartlepool 001F      E01033465
#
#    Total: All usual residents aged 16 years and over in employment the week before the census  \
# 0                                                951
# 1                                                555
# 2                                                520
# 3                                                760
# 4                                               1029
#
#    Less than 2km  2km to less than 5km  60km and over  Works mainly from home
# 0            125                   206             20                     113
# 1             33                   130             17                      82
# 2             14                   104             19                     102
# 3             41                   135             20                     145
# 4             63                   175             26                     228

# %%
DF['percent TFW less than 2km'] = DF['Less than 2km'] / DF['Total: All usual residents aged 16 years and over in employment the week before the census']

DF['percent TFW 2km to 5km'] = DF['2km to less than 5km'] / DF['Total: All usual residents aged 16 years and over in employment the week before the census']

DF['percent TFW 60km and over'] = DF['60km and over'] / DF['Total: All usual residents aged 16 years and over in employment the week before the census']

DF['percent WFH'] = DF['Works mainly from home'] / DF['Total: All usual residents aged 16 years and over in employment the week before the census']

# %%
df_distance2work = DF[['geography code', 'percent TFW less than 2km',\
                       'percent TFW 2km to 5km',\
       'percent TFW 60km and over', 'percent WFH']].set_index(['geography code'])

# %% [markdown]
# # Hours worked

# %%
first_f = 'hours_worked.csv' 
DF = pd.read_csv(data_folder + first_f).\
    rename(columns={'mnemonic':'geography code'})

# %%
DF.head()
# Out:
#   2021 super output area - lower layer geography code  \
# 0                      Hartlepool 001A      E01011954
# 1                      Hartlepool 001B      E01011969
# 2                      Hartlepool 001C      E01011970
# 3                      Hartlepool 001D      E01011971
# 4                      Hartlepool 001F      E01033465
#
#    Total: All usual residents aged 16 years and over in employment the week before the census  \
# 0                                                952
# 1                                                556
# 2                                                521
# 3                                                759
# 4                                               1028
#
#    Part-time  Part-time: 15 hours or less worked  Full-time  \
# 0        331                                  80        621
# 1        146                                  42        410
# 2        144                                  35        377
# 3        209                                  55        550
# 4        268                                  69        760
#
#    Full-time: 49 or more hours worked
# 0                                  70
# 1                                  50
# 2                                  58
# 3                                  74
# 4                                 119

# %%
DF['percent part-time'] = DF['Part-time'] / DF['Total: All usual residents aged 16 years and over in employment the week before the census']

DF['percent 15 hours or less worked'] = DF['Part-time: 15 hours or less worked'] / DF['Total: All usual residents aged 16 years and over in employment the week before the census']

# DF['percent full-time'] = DF['Full-time'] / DF['Total: All usual residents aged 16 years and over in employment the week before the census']

DF['percent 49 or more hours worked'] = DF['Full-time: 49 or more hours worked'] / DF['Total: All usual residents aged 16 years and over in employment the week before the census']

# %%
df_hours_worked = DF[['geography code', 'percent part-time',\
                      'percent 15 hours or less worked',\
                      'percent 49 or more hours worked']].set_index(['geography code'])

# %% [markdown]
# ## Commute type

# %%
first_f = 'commute_type.csv' 
DF = pd.read_csv(data_folder + first_f).\
    rename(columns={'mnemonic':'geography code'})

DF.head()
# Out:
#   2021 super output area - lower layer geography code  \
# 0                      Hartlepool 001A      E01011954
# 1                      Hartlepool 001B      E01011969
# 2                      Hartlepool 001C      E01011970
# 3                      Hartlepool 001D      E01011971
# 4                      Hartlepool 001F      E01033465
#
#    Total: All usual residents aged 16 years and over in employment the week before the census  \
# 0                                                950
# 1                                                556
# 2                                                522
# 3                                                762
# 4                                               1026
#
#    Work mainly at or from home  Underground, metro, light rail, tram  Train  \
# 0                          113                                     0      3
# 1                           82                                     0      5
# 2                          102                                     0      8
# 3                          145                                     0      5
# 4                          228                                     2     10
#
#    Bus, minibus or coach  Taxi  Motorcycle, scooter or moped  \
# 0                     39    19                             3
# 1                     16     4                             1
# 2                     14     3                             4
# 3                     12     4                             0
# 4                     15    11                             1
#
#    Driving a car or van  Passenger in a car or van  Bicycle  On foot
# 0                   604                         71       14       77
# 1                   376                         37        8       16
# 2                   342                         28        3       13
# 3                   519                         43        3       20
# 4                   672                         37        5       28

# %%
# DF['percent commute metro rail'] = DF['Underground, metro, light rail, tram'] / DF['Total: All usual residents aged 16 years and over in employment the week before the census']

# DF['percent commute train'] = DF['Train'] / DF['Total: All usual residents aged 16 years and over in employment the week before the census']

# DF['percent commute car'] = DF['Driving a car or van'] / DF['Total: All usual residents aged 16 years and over in employment the week before the census']

DF['percent commute bus'] = DF['Bus, minibus or coach'] / DF['Total: All usual residents aged 16 years and over in employment the week before the census']

DF['percent commute bicycle'] = DF['Bicycle'] / DF['Total: All usual residents aged 16 years and over in employment the week before the census']

DF['percent commute on foot'] = DF['On foot'] / DF['Total: All usual residents aged 16 years and over in employment the week before the census']

# %%
df_commute = DF[['geography code', 'percent commute on foot',\
         'percent commute bus', 'percent commute bicycle']].\
        set_index(['geography code'])

# %% [markdown]
# ## Population density

# %%
f2 = 'popdensity-nomis_2023_03_01_224549.csv'
df = pd.read_csv(data_folder1 + f2)
# df['geography'] = df['LSOA_2021'].apply(lambda x: str(x).split(':')[1])
df['geography code'] = df['LSOA_2021'].apply(lambda x: str(x).split(' : ')[0])
del df['LSOA_2021']
df['pop_density'] = df['pop_density'].str.replace(',', '').astype(float)
df_pop = df.copy()
df_pop = df_pop.set_index(['geography code'])
df_pop.head()
# Out:
#                 pop_density
# geography code
# E01011954            5432.9
# E01011969            1430.7
# E01011970            2913.9
# E01011971            6049.4
# E01033465            4311.9

# %% [markdown]
# # Merge all into second part

# %%
DF_second_part = df_ethnic.join(df_religion).join(df_heating).\
        join(df_distance2work).join(df_hours_worked).join(df_commute).\
        join(df_pop)
DF_second_part.head()
# Out:
#                 percent asian  percent black  percent mixed  percent white  \
# geography code
# E01011954            0.008319       0.000000       0.002627       0.984238
# E01011969            0.004461       0.000000       0.004461       0.988104
# E01011970            0.006542       0.000000       0.003738       0.989720
# E01011971            0.003779       0.000000       0.003779       0.990930
# E01033465            0.006141       0.001024       0.005629       0.979529
#
#                 percent christian  percent jewish  percent no religion  \
# geography code
# E01011954                0.487078        0.000000             0.452475
# E01011969                0.659226        0.000744             0.295387
# E01011970                0.638318        0.002804             0.308411
# E01011971                0.602419        0.000756             0.339380
# E01033465                0.578517        0.000512             0.362148
#
#                 percent muslim  percent no central heating  \
# geography code
# E01011954             0.006570                    0.006224
# E01011969             0.000000                    0.008292
# E01011970             0.000000                    0.020661
# E01011971             0.002268                    0.000000
# E01033465             0.005115                    0.000000
#
#                 percent wood heating  ...  percent TFW 2km to 5km  \
# geography code                        ...
# E01011954                        0.0  ...                0.216614
# E01011969                        0.0  ...                0.234234
# E01011970                        0.0  ...                0.200000
# E01011971                        0.0  ...                0.177632
# E01033465                        0.0  ...                0.170068
#
#                 percent TFW 60km and over  percent WFH  percent part-time  \
# geography code
# E01011954                        0.021030     0.118822           0.347689
# E01011969                        0.030631     0.147748           0.262590
# E01011970                        0.036538     0.196154           0.276392
# E01011971                        0.026316     0.190789           0.275362
# E01033465                        0.025267     0.221574           0.260700
#
#                 percent 15 hours or less worked  \
# geography code
# E01011954                              0.084034
# E01011969                              0.075540
# E01011970                              0.067179
# E01011971                              0.072464
# E01033465                              0.067121
#
#                 percent 49 or more hours worked  percent commute on foot  \
# geography code
# E01011954                              0.073529                 0.081053
# E01011969                              0.089928                 0.028777
# E01011970                              0.111324                 0.024904
# E01011971                              0.097497                 0.026247
# E01033465                              0.115759                 0.027290
#
#                 percent commute bus  percent commute bicycle  pop_density
# geography code
# E01011954                  0.041053                 0.014737       5432.9
# E01011969                  0.028777                 0.014388       1430.7
# E01011970                  0.026820                 0.005747       2913.9
# E01011971                  0.015748                 0.003937       6049.4
# E01033465                  0.014620                 0.004873       4311.9
#
# [5 rows x 22 columns]

# %% [markdown]
# # Save second part

# %%
DF_second_part.to_csv('../data/glavni/controls_second_group.csv')

# %% [markdown]
# # Read in the first part

# %%
DF_first_part = pd.read_csv('../data/glavni/controls_first_group.csv')

# %% [markdown]
# # Merge first and second groups

# %%
DF_full = DF_second_part.merge(DF_first_part, on=['geography code'])

# %% [markdown]
# # Save

# %%
DF_full.to_csv('../data/glavni/controls.csv', index=None)

# %%
print (len(DF_full.columns))
# Out:
# 35

# %%
print (list(DF_full.columns))
# Out:
# ['geography code', 'percent asian', 'percent black', 'percent mixed', 'percent white', 'percent christian', 'percent jewish', 'percent no religion', 'percent muslim', 'percent no central heating', 'percent wood heating', 'percent communal heating', 'percent TFW less than 2km', 'percent TFW 2km to 5km', 'percent TFW 60km and over', 'percent WFH', 'percent part-time', 'percent 15 hours or less worked', 'percent 49 or more hours worked', 'percent commute on foot', 'percent commute bus', 'percent commute bicycle', 'pop_density', 'geography', 'percent children up to 14', 'percent aged 65plus', 'percent married or in civil partnership', 'percent unemployed', 'percent very good health', 'percent bad health', 'percent poor-english', 'percent highly-deprived', 'percent mid-deprived', 'percent male', 'total population']

# %%
print (len(DF))
# Out:
# 35672
