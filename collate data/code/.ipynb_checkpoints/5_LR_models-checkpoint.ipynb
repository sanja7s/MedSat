# %%
# !pip install --upgrade pandas

# %%
# import requests
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm

import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.iolib.summary2 import summary_col

from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

from sklearn.preprocessing import StandardScaler

# %%
# %matplotlib inline
# Set the style
plt.style.use('fivethirtyeight')

# %% [markdown]
# # Get Data

# %%
data = pd.read_csv('../data/glavni/standardized_master.csv')

# %%
data.head()
# Out:
#   geography code  c_percent asian  c_percent black  c_percent mixed  \
# 0      E01011954        -0.573385        -0.570268        -1.258196
# 1      E01011969        -0.601535        -0.570268        -1.168113
# 2      E01011970        -0.586349        -0.570268        -1.203608
# 3      E01011971        -0.606509        -0.570268        -1.201596
# 4      E01033465        -0.589274        -0.554921        -1.110717
#
#    c_percent white  c_percent christian  c_percent jewish  \
# 0         0.779769             0.140924         -0.169233
# 1         0.798901             1.756852         -0.142537
# 2         0.806896             1.560587         -0.068638
# 3         0.812885             1.223608         -0.142113
# 4         0.756465             0.999242         -0.150880
#
#    c_percent no religion  c_percent muslim  c_percent no central heating  ...  \
# 0               0.779456         -0.455572                     -0.805327  ...
# 1              -0.669599         -0.511178                     -0.608010  ...
# 2              -0.549457         -0.511178                      0.572306  ...
# 3              -0.263784         -0.491987                     -1.399247  ...
# 4              -0.053760         -0.467888                     -1.399247  ...
#
#    c_percent male  c_total population  o_diabetes_quantity_per_capita  \
# 0       -0.733140            1.711880                        0.466883
# 1        0.268084           -1.044317                        0.407747
# 2       -0.142462           -2.265527                        0.490721
# 3       -0.409958           -1.146051                        0.269708
# 4        0.401818            0.897364                       -0.017278
#
#    o_opioids_quantity_per_capita  o_OME_per_capita  \
# 0                       2.833737          1.811354
# 1                       2.791734          1.803824
# 2                       2.785662          1.838707
# 3                       2.600094          1.676021
# 4                       2.282628          1.527793
#
#    o_total_quantity_per_capita     e_NO2  e_ozone  \
# 0                     0.399787 -1.022614  1.08637
# 1                     0.382881 -1.076962  1.08637
# 2                     0.399761 -1.050979  1.08637
# 3                     0.338375 -1.023140  1.08637
# 4                     0.235703 -0.998307  1.08637
#
#    e_total_aerosol_optical_depth_at_550nm_surface  \
# 0                                       -1.752366
# 1                                       -1.752366
# 2                                       -1.752366
# 3                                       -1.752366
# 4                                       -1.752366
#
#    e_particulate_matter_d_less_than_25_um_surface
# 0                                       -1.032455
# 1                                       -1.032455
# 2                                       -1.032455
# 3                                       -1.032455
# 4                                       -1.032455
#
# [5 rows x 43 columns]

# %%
len(data.columns), data.columns
# Out:
# (43,
#  Index(['geography code', 'c_percent asian', 'c_percent black',
#         'c_percent mixed', 'c_percent white', 'c_percent christian',
#         'c_percent jewish', 'c_percent no religion', 'c_percent muslim',
#         'c_percent no central heating', 'c_percent wood heating',
#         'c_percent communal heating', 'c_percent TFW less than 2km',
#         'c_percent TFW 2km to 5km', 'c_percent TFW 60km and over',
#         'c_percent WFH', 'c_percent part-time',
#         'c_percent 15 hours or less worked',
#         'c_percent 49 or more hours worked', 'c_percent commute on foot',
#         'c_percent commute bus', 'c_percent commute bicycle', 'c_pop_density',
#         'geography', 'c_percent children up to 14', 'c_percent aged 65plus',
#         'c_percent married or in civil partnership', 'c_percent unemployed',
#         'c_percent very good health', 'c_percent bad health',
#         'c_percent poor-english', 'c_percent highly-deprived',
#         'c_percent mid-deprived', 'c_percent male', 'c_total population',
#         'o_diabetes_quantity_per_capita', 'o_opioids_quantity_per_capita',
#         'o_OME_per_capita', 'o_total_quantity_per_capita', 'e_NO2', 'e_ozone',
#         'e_total_aerosol_optical_depth_at_550nm_surface',
#         'e_particulate_matter_d_less_than_25_um_surface'],
#        dtype='object'))

# %%
data.hist(figsize=(30,40), layout=(12,6));

# %%
del data['c_percent aged 65plus']
del data['c_percent mid-deprived']
del data['c_percent asian']

# %%
controls = [c for c in data.columns if c.startswith('c_')]
predfeats = data[controls].copy()

fig, ax = plt.subplots(figsize=(44,44))         
corr = predfeats.corr(method='pearson')
heatmap = sns.heatmap(corr, annot=True , ax=ax ,cmap='coolwarm' , annot_kws={"fontsize":20}, vmin=-1, vmax=1 )
ax.set_xticklabels(corr.columns, fontsize=20 , rotation = 90)
ax.set_yticklabels(corr.columns, fontsize=20, rotation = 0)
cbar = heatmap.collections[0].colorbar
cbar.ax.tick_params(labelsize=20)

# Use tight_layout to adjust the padding between the subplots
# plt.tight_layout()

# fig.savefig('../res7s/correlogram_vitaminN7s.png', dpi=300)

# %% [markdown]
# # Define Data Inputs to the Models

# %%
controls = [c for c in data.columns if c.startswith("c_")]
environment = [c for c in data.columns if c.startswith("e_")]
outcomes = [c for c in data.columns if c.startswith("o_")]

features = controls + environment

# %%
outcome = 'o_diabetes_quantity_per_capita'

# %% [markdown]
# # VIF Colinearity

# %%
X = data[features].dropna()

# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
print(vif_data)
# Out:
#                                            feature         VIF
# 0                                  c_percent asian   77.496577
# 1                                  c_percent black   26.476769
# 2                                  c_percent mixed    6.748935
# 3                                  c_percent white  234.382774
# 4                              c_percent christian   26.884551
# 5                                 c_percent jewish    2.946235
# 6                            c_percent no religion   32.441441
# 7                                 c_percent muslim    8.572122
# 8                     c_percent no central heating    1.810904
# 9                           c_percent wood heating    1.947718
# 10                      c_percent communal heating    1.260388
# 11                     c_percent TFW less than 2km    6.449485
# 12                        c_percent TFW 2km to 5km    2.085559
# 13                     c_percent TFW 60km and over    1.659011
# 14                                   c_percent WFH    7.528720
# 15                             c_percent part-time    6.024856
# 16               c_percent 15 hours or less worked    4.986797
# 17               c_percent 49 or more hours worked    3.126197
# 18                       c_percent commute on foot    6.326273
# 19                           c_percent commute bus    4.270056
# 20                       c_percent commute bicycle    1.756086
# 21                                   c_pop_density    3.363842
# 22                     c_percent children up to 14    2.708446
# 23                           c_percent aged 65plus   12.036123
# 24       c_percent married or in civil partnership    8.877528
# 25                            c_percent unemployed    6.452005
# 26                      c_percent very good health    7.725771
# 27                            c_percent bad health    5.768567
# 28                          c_percent poor-english    5.132658
# 29                       c_percent highly-deprived    1.597536
# 30                          c_percent mid-deprived    8.724270
# 31                                  c_percent male    1.425125
# 32                              c_total population    1.303344
# 33                                           e_NO2    4.173789
# 34                                         e_ozone    1.720475
# 35  e_total_aerosol_optical_depth_at_550nm_surface    4.146354
# 36  e_particulate_matter_d_less_than_25_um_surface    2.647632

# %% [markdown]
# # Functions

# %%
def LR(data=data, index_column="geography code", label=outcome, features_columns=features):
	
	data2 = data.copy()
	
	target = data2[[index_column, label]]
	features = data2[features_columns]
	
	X = features.values
	y = target[label].values
	
	X = sm.add_constant(X)  
	model = sm.OLS(y,X, missing='drop')	
	results = model.fit()
	
	print ("LABEL ", label)
	print_model = results.summary(xname=['intercept']+features_columns, yname =  outcome)
	print (print_model)
	
	return results.rsquared_adj

# %% [markdown]
# # Apply Models

# %% [markdown]
# ## Opioids

# %%
outcome = "o_opioids_quantity_per_capita"
LR(data=data, index_column="geography code", label=outcome, features_columns=features)
# Out:
# LABEL  o_opioids_quantity_per_capita
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     o_opioids_quantity_per_capita   R-squared:                       0.528
# Model:                                       OLS   Adj. R-squared:                  0.527
# Method:                            Least Squares   F-statistic:                     553.7
# Date:                           Sun, 19 Mar 2023   Prob (F-statistic):               0.00
# Time:                                   00:15:52   Log-Likelihood:                -18139.
# No. Observations:                          17383   AIC:                         3.635e+04
# Df Residuals:                              17347   BIC:                         3.663e+04
# Df Model:                                     35
# Covariance Type:                       nonrobust
# ==================================================================================================================
#                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# intercept                                         -0.0010      0.005     -0.197      0.844      -0.011       0.009
# c_percent black                                    0.0129      0.011      1.172      0.241      -0.009       0.034
# c_percent mixed                                   -0.0605      0.010     -6.082      0.000      -0.080      -0.041
# c_percent white                                    0.0117      0.015      0.757      0.449      -0.019       0.042
# c_percent christian                                0.0543      0.013      4.159      0.000       0.029       0.080
# c_percent jewish                                   0.0046      0.007      0.647      0.517      -0.009       0.018
# c_percent no religion                              0.0708      0.014      4.917      0.000       0.043       0.099
# c_percent muslim                                  -0.1013      0.012     -8.337      0.000      -0.125      -0.077
# c_percent no central heating                      -0.0871      0.007    -12.767      0.000      -0.100      -0.074
# c_percent wood heating                            -0.0271      0.008     -3.273      0.001      -0.043      -0.011
# c_percent communal heating                         0.0014      0.006      0.226      0.821      -0.011       0.014
# c_percent TFW less than 2km                        0.0627      0.013      4.657      0.000       0.036       0.089
# c_percent TFW 2km to 5km                          -0.0363      0.008     -4.651      0.000      -0.052      -0.021
# c_percent TFW 60km and over                        0.0248      0.007      3.721      0.000       0.012       0.038
# c_percent WFH                                     -0.1536      0.013    -12.187      0.000      -0.178      -0.129
# c_percent part-time                               -0.0828      0.012     -6.952      0.000      -0.106      -0.059
# c_percent 15 hours or less worked                  0.0297      0.012      2.541      0.011       0.007       0.053
# c_percent 49 or more hours worked                  0.0257      0.009      2.775      0.006       0.008       0.044
# c_percent commute on foot                         -0.0816      0.013     -6.089      0.000      -0.108      -0.055
# c_percent commute bus                              0.0501      0.010      5.065      0.000       0.031       0.069
# c_percent commute bicycle                         -0.0641      0.007     -9.166      0.000      -0.078      -0.050
# c_pop_density                                      0.0303      0.011      2.741      0.006       0.009       0.052
# c_percent children up to 14                       -0.0544      0.009     -6.339      0.000      -0.071      -0.038
# c_percent married or in civil partnership          0.0424      0.013      3.169      0.002       0.016       0.069
# c_percent unemployed                              -0.0448      0.010     -4.294      0.000      -0.065      -0.024
# c_percent very good health                        -0.0297      0.012     -2.446      0.014      -0.054      -0.006
# c_percent bad health                               0.2561      0.011     22.849      0.000       0.234       0.278
# c_percent poor-english                            -0.0412      0.011     -3.584      0.000      -0.064      -0.019
# c_percent highly-deprived                         -0.0070      0.007     -1.053      0.293      -0.020       0.006
# c_percent male                                     0.0133      0.006      2.175      0.030       0.001       0.025
# c_total population                                 0.0187      0.006      3.167      0.002       0.007       0.030
# e_NO2                                             -0.1718      0.010    -17.113      0.000      -0.192      -0.152
# e_ozone                                           -0.0143      0.007     -2.083      0.037      -0.028      -0.001
# e_total_aerosol_optical_depth_at_550nm_surface    -0.4136      0.011    -36.800      0.000      -0.436      -0.392
# e_particulate_matter_d_less_than_25_um_surface     0.1751      0.009     19.803      0.000       0.158       0.192
# e_ndvi                                            -0.0348      0.008     -4.270      0.000      -0.051      -0.019
# ==============================================================================
# Omnibus:                      563.784   Durbin-Watson:                   0.432
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1538.833
# Skew:                          -0.064   Prob(JB):                         0.00
# Kurtosis:                       4.452   Cond. No.                         12.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.5267182067684031

# %%
outcome = "o_OME_per_capita"
LR(data=data, index_column="geography code", label=outcome, features_columns=features)
# Out:
# LABEL  o_OME_per_capita
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       o_OME_per_capita   R-squared:                       0.289
# Model:                            OLS   Adj. R-squared:                  0.288
# Method:                 Least Squares   F-statistic:                     201.8
# Date:                Sun, 19 Mar 2023   Prob (F-statistic):               0.00
# Time:                        00:16:05   Log-Likelihood:                -21703.
# No. Observations:               17383   AIC:                         4.348e+04
# Df Residuals:                   17347   BIC:                         4.376e+04
# Df Model:                          35
# Covariance Type:            nonrobust
# ==================================================================================================================
#                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# intercept                                         -0.0003      0.006     -0.050      0.960      -0.013       0.012
# c_percent black                                    0.0513      0.013      3.811      0.000       0.025       0.078
# c_percent mixed                                   -0.0280      0.012     -2.290      0.022      -0.052      -0.004
# c_percent white                                    0.1657      0.019      8.747      0.000       0.129       0.203
# c_percent christian                                0.0563      0.016      3.519      0.000       0.025       0.088
# c_percent jewish                                  -0.0500      0.009     -5.760      0.000      -0.067      -0.033
# c_percent no religion                              0.0487      0.018      2.757      0.006       0.014       0.083
# c_percent muslim                                  -0.0143      0.015     -0.958      0.338      -0.044       0.015
# c_percent no central heating                      -0.0046      0.008     -0.547      0.584      -0.021       0.012
# c_percent wood heating                            -0.0216      0.010     -2.128      0.033      -0.042      -0.002
# c_percent communal heating                        -0.0422      0.008     -5.385      0.000      -0.058      -0.027
# c_percent TFW less than 2km                        0.1243      0.017      7.529      0.000       0.092       0.157
# c_percent TFW 2km to 5km                           0.0402      0.010      4.185      0.000       0.021       0.059
# c_percent TFW 60km and over                        0.0001      0.008      0.016      0.988      -0.016       0.016
# c_percent WFH                                     -0.1532      0.015     -9.900      0.000      -0.184      -0.123
# c_percent part-time                               -0.0977      0.015     -6.687      0.000      -0.126      -0.069
# c_percent 15 hours or less worked                  0.0827      0.014      5.754      0.000       0.054       0.111
# c_percent 49 or more hours worked                 -0.0761      0.011     -6.702      0.000      -0.098      -0.054
# c_percent commute on foot                         -0.0791      0.016     -4.811      0.000      -0.111      -0.047
# c_percent commute bus                             -0.0802      0.012     -6.611      0.000      -0.104      -0.056
# c_percent commute bicycle                         -0.1445      0.009    -16.844      0.000      -0.161      -0.128
# c_pop_density                                      0.0181      0.014      1.332      0.183      -0.009       0.045
# c_percent children up to 14                        0.0045      0.011      0.430      0.667      -0.016       0.025
# c_percent married or in civil partnership          0.1043      0.016      6.352      0.000       0.072       0.137
# c_percent unemployed                              -0.0485      0.013     -3.787      0.000      -0.074      -0.023
# c_percent very good health                        -0.0980      0.015     -6.574      0.000      -0.127      -0.069
# c_percent bad health                               0.1061      0.014      7.710      0.000       0.079       0.133
# c_percent poor-english                             0.0060      0.014      0.424      0.672      -0.022       0.034
# c_percent highly-deprived                         -0.0134      0.008     -1.643      0.100      -0.029       0.003
# c_percent male                                     0.0387      0.007      5.163      0.000       0.024       0.053
# c_total population                                 0.0339      0.007      4.669      0.000       0.020       0.048
# e_NO2                                             -0.0818      0.012     -6.639      0.000      -0.106      -0.058
# e_ozone                                           -0.0223      0.008     -2.658      0.008      -0.039      -0.006
# e_total_aerosol_optical_depth_at_550nm_surface    -0.1817      0.014    -13.174      0.000      -0.209      -0.155
# e_particulate_matter_d_less_than_25_um_surface     0.1246      0.011     11.484      0.000       0.103       0.146
# e_ndvi                                             0.0536      0.010      5.350      0.000       0.034       0.073
# ==============================================================================
# Omnibus:                     5450.352   Durbin-Watson:                   0.466
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            37342.761
# Skew:                          -1.332   Prob(JB):                         0.00
# Kurtosis:                       9.668   Cond. No.                         12.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.28793658749339646

# %% [markdown]
# ## Diabetes

# %%
outcome = "o_diabetes_quantity_per_capita"
LR(data=data, index_column="geography code", label=outcome, features_columns=features)
# Out:
# LABEL  o_diabetes_quantity_per_capita
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     o_diabetes_quantity_per_capita   R-squared:                       0.245
# Model:                                        OLS   Adj. R-squared:                  0.244
# Method:                             Least Squares   F-statistic:                     161.1
# Date:                            Sun, 19 Mar 2023   Prob (F-statistic):               0.00
# Time:                                    00:16:13   Log-Likelihood:                -22218.
# No. Observations:                           17383   AIC:                         4.451e+04
# Df Residuals:                               17347   BIC:                         4.479e+04
# Df Model:                                      35
# Covariance Type:                        nonrobust
# ==================================================================================================================
#                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# intercept                                         -0.0007      0.007     -0.099      0.921      -0.014       0.012
# c_percent black                                    0.0788      0.014      5.682      0.000       0.052       0.106
# c_percent mixed                                   -0.0516      0.013     -4.103      0.000      -0.076      -0.027
# c_percent white                                   -0.1104      0.020     -5.656      0.000      -0.149      -0.072
# c_percent christian                                0.0508      0.016      3.077      0.002       0.018       0.083
# c_percent jewish                                  -0.0568      0.009     -6.352      0.000      -0.074      -0.039
# c_percent no religion                             -0.1260      0.018     -6.922      0.000      -0.162      -0.090
# c_percent muslim                                  -0.0561      0.015     -3.648      0.000      -0.086      -0.026
# c_percent no central heating                      -0.0145      0.009     -1.684      0.092      -0.031       0.002
# c_percent wood heating                            -0.0232      0.010     -2.213      0.027      -0.044      -0.003
# c_percent communal heating                        -0.0427      0.008     -5.292      0.000      -0.059      -0.027
# c_percent TFW less than 2km                        0.0940      0.017      5.528      0.000       0.061       0.127
# c_percent TFW 2km to 5km                          -0.0879      0.010     -8.892      0.000      -0.107      -0.069
# c_percent TFW 60km and over                       -0.0174      0.008     -2.063      0.039      -0.034      -0.001
# c_percent WFH                                     -0.2682      0.016    -16.829      0.000      -0.299      -0.237
# c_percent part-time                               -0.1914      0.015    -12.718      0.000      -0.221      -0.162
# c_percent 15 hours or less worked                  0.1553      0.015     10.495      0.000       0.126       0.184
# c_percent 49 or more hours worked                 -0.0156      0.012     -1.333      0.183      -0.039       0.007
# c_percent commute on foot                         -0.1242      0.017     -7.329      0.000      -0.157      -0.091
# c_percent commute bus                             -0.0491      0.013     -3.927      0.000      -0.074      -0.025
# c_percent commute bicycle                         -0.1373      0.009    -15.539      0.000      -0.155      -0.120
# c_pop_density                                      0.0507      0.014      3.633      0.000       0.023       0.078
# c_percent children up to 14                        0.0068      0.011      0.627      0.531      -0.014       0.028
# c_percent married or in civil partnership          0.0686      0.017      4.057      0.000       0.035       0.102
# c_percent unemployed                              -0.1234      0.013     -9.353      0.000      -0.149      -0.098
# c_percent very good health                        -0.1925      0.015    -12.539      0.000      -0.223      -0.162
# c_percent bad health                               0.1751      0.014     12.357      0.000       0.147       0.203
# c_percent poor-english                            -0.0245      0.015     -1.684      0.092      -0.053       0.004
# c_percent highly-deprived                         -0.0039      0.008     -0.466      0.641      -0.020       0.013
# c_percent male                                     0.0313      0.008      4.057      0.000       0.016       0.046
# c_total population                                 0.0325      0.007      4.357      0.000       0.018       0.047
# e_NO2                                             -0.0419      0.013     -3.301      0.001      -0.067      -0.017
# e_ozone                                           -0.0417      0.009     -4.818      0.000      -0.059      -0.025
# e_total_aerosol_optical_depth_at_550nm_surface    -0.0933      0.014     -6.567      0.000      -0.121      -0.065
# e_particulate_matter_d_less_than_25_um_surface     0.1894      0.011     16.943      0.000       0.167       0.211
# e_ndvi                                             0.0567      0.010      5.494      0.000       0.036       0.077
# ==============================================================================
# Omnibus:                     1865.795   Durbin-Watson:                   0.462
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2744.539
# Skew:                          -0.815   Prob(JB):                         0.00
# Kurtosis:                       4.063   Cond. No.                         12.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.24378505243363802

# %% [markdown]
# # Total Prescriptions

# %%
outcome = "o_total_quantity_per_capita"
LR(data=data, index_column="geography code", label=outcome, features_columns=features)
# Out:
# LABEL  o_total_quantity_per_capita
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:     o_total_quantity_per_capita   R-squared:                       0.175
# Model:                                     OLS   Adj. R-squared:                  0.174
# Method:                          Least Squares   F-statistic:                     105.3
# Date:                         Sun, 19 Mar 2023   Prob (F-statistic):               0.00
# Time:                                 00:16:18   Log-Likelihood:                -22996.
# No. Observations:                        17383   AIC:                         4.606e+04
# Df Residuals:                            17347   BIC:                         4.634e+04
# Df Model:                                   35
# Covariance Type:                     nonrobust
# ==================================================================================================================
#                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# intercept                                         -0.0009      0.007     -0.129      0.897      -0.014       0.013
# c_percent black                                    0.0797      0.015      5.494      0.000       0.051       0.108
# c_percent mixed                                   -0.0311      0.013     -2.362      0.018      -0.057      -0.005
# c_percent white                                    0.0638      0.020      3.125      0.002       0.024       0.104
# c_percent christian                                0.1048      0.017      6.073      0.000       0.071       0.139
# c_percent jewish                                  -0.0300      0.009     -3.202      0.001      -0.048      -0.012
# c_percent no religion                             -0.0467      0.019     -2.453      0.014      -0.084      -0.009
# c_percent muslim                                  -0.0080      0.016     -0.496      0.620      -0.039       0.024
# c_percent no central heating                       0.0018      0.009      0.203      0.839      -0.016       0.020
# c_percent wood heating                            -0.0344      0.011     -3.146      0.002      -0.056      -0.013
# c_percent communal heating                        -0.0437      0.008     -5.178      0.000      -0.060      -0.027
# c_percent TFW less than 2km                        0.1328      0.018      7.464      0.000       0.098       0.168
# c_percent TFW 2km to 5km                           0.0393      0.010      3.807      0.000       0.019       0.060
# c_percent TFW 60km and over                       -0.0150      0.009     -1.702      0.089      -0.032       0.002
# c_percent WFH                                     -0.0838      0.017     -5.027      0.000      -0.116      -0.051
# c_percent part-time                               -0.1096      0.016     -6.961      0.000      -0.140      -0.079
# c_percent 15 hours or less worked                  0.1295      0.015      8.366      0.000       0.099       0.160
# c_percent 49 or more hours worked                 -0.0386      0.012     -3.159      0.002      -0.063      -0.015
# c_percent commute on foot                         -0.0697      0.018     -3.937      0.000      -0.104      -0.035
# c_percent commute bus                             -0.1022      0.013     -7.812      0.000      -0.128      -0.077
# c_percent commute bicycle                         -0.1594      0.009    -17.255      0.000      -0.178      -0.141
# c_pop_density                                      0.0275      0.015      1.882      0.060      -0.001       0.056
# c_percent children up to 14                        0.0442      0.011      3.897      0.000       0.022       0.066
# c_percent married or in civil partnership          0.0431      0.018      2.437      0.015       0.008       0.078
# c_percent unemployed                              -0.1017      0.014     -7.373      0.000      -0.129      -0.075
# c_percent very good health                        -0.1409      0.016     -8.772      0.000      -0.172      -0.109
# c_percent bad health                               0.0967      0.015      6.526      0.000       0.068       0.126
# c_percent poor-english                            -0.0154      0.015     -1.013      0.311      -0.045       0.014
# c_percent highly-deprived                         -0.0154      0.009     -1.753      0.080      -0.033       0.002
# c_percent male                                     0.0323      0.008      4.001      0.000       0.016       0.048
# c_total population                                 0.0332      0.008      4.243      0.000       0.018       0.048
# e_NO2                                             -0.0440      0.013     -3.315      0.001      -0.070      -0.018
# e_ozone                                           -0.0703      0.009     -7.765      0.000      -0.088      -0.053
# e_total_aerosol_optical_depth_at_550nm_surface    -0.2692      0.015    -18.113      0.000      -0.298      -0.240
# e_particulate_matter_d_less_than_25_um_surface     0.2505      0.012     21.429      0.000       0.228       0.273
# e_ndvi                                             0.0852      0.011      7.898      0.000       0.064       0.106
# ==============================================================================
# Omnibus:                    13200.666   Durbin-Watson:                   0.461
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           260902.967
# Skew:                          -3.564   Prob(JB):                         0.00
# Kurtosis:                      20.590   Cond. No.                         12.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.1735061354790992
