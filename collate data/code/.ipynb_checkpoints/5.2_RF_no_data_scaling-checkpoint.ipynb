# %%
# !pip install --upgrade pandas

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import StandardScaler
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split
from sklearn.model_selection import ShuffleSplit
from sklearn.metrics import r2_score
from collections import defaultdict

from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# %matplotlib inline
# Set the style
plt.style.use('fivethirtyeight')

# %%
# Predict Prescriptions Prevalence from the data as is,
# without any type of  preprocessing (e.g., scalling or logging)

# %% [markdown]
# # Get Data

# %%
data = pd.read_csv('../data/glavni/raw_master.csv')

# %%
controls = [c for c in data.columns if c.startswith("c_")]
environment = [c for c in data.columns if c.startswith("e_")]
outcomes = [c for c in data.columns if c.startswith("o_")]

features = controls + environment

# %%
data.head()
# Out:
#   geography code  c_percent asian  c_percent black  c_percent mixed  \
# 0      E01011954         0.008319         0.000000         0.002627
# 1      E01011969         0.004461         0.000000         0.004461
# 2      E01011970         0.006542         0.000000         0.003738
# 3      E01011971         0.003779         0.000000         0.003779
# 4      E01033465         0.006141         0.001024         0.005629
#
#    c_percent white  c_percent christian  c_percent jewish  \
# 0         0.984238             0.487078          0.000000
# 1         0.988104             0.659226          0.000744
# 2         0.989720             0.638318          0.002804
# 3         0.990930             0.602419          0.000756
# 4         0.979529             0.578517          0.000512
#
#    c_percent no religion  c_percent muslim  c_percent no central heating  ...  \
# 0               0.452475          0.006570                      0.006224  ...
# 1               0.295387          0.000000                      0.008292  ...
# 2               0.308411          0.000000                      0.020661  ...
# 3               0.339380          0.002268                      0.000000  ...
# 4               0.362148          0.005115                      0.000000  ...
#
#    c_total population  o_diabetes_quantity_per_capita  \
# 0                2284                       46.662545
# 1                1347                       45.697397
# 2                1066                       47.051596
# 3                1321                       43.444496
# 4                1954                       38.760661
#
#    o_opioids_quantity_per_capita  o_OME_per_capita  \
# 0                      88.287946       2378.380263
# 1                      87.425625       2357.003462
# 2                      87.300963       2457.675905
# 3                      83.491280       2022.128240
# 4                      76.973734       1692.863363
#
#    o_total_quantity_per_capita     e_NO2     e_ozone  \
# 0                  1358.022385  0.000092  330.030675
# 1                  1338.559208  0.000091  330.030675
# 2                  1357.992070  0.000091  330.030675
# 3                  1288.643555  0.000092  330.030675
# 4                  1180.476551  0.000092  330.030675
#
#    e_total_aerosol_optical_depth_at_550nm_surface  \
# 0                                        0.119333
# 1                                        0.119333
# 2                                        0.119333
# 3                                        0.119333
# 4                                        0.119333
#
#    e_particulate_matter_d_less_than_25_um_surface    e_ndvi
# 0                                    6.103186e-09  0.427852
# 1                                    6.103186e-09  0.516154
# 2                                    6.103186e-09  0.479152
# 3                                    6.103186e-09  0.406105
# 4                                    6.103186e-09  0.443469
#
# [5 rows x 44 columns]

# %%
len(data.columns), data.columns
# Out:
# (44,
#  Index(['geography code', 'c_percent asian', 'c_percent black',
#         'c_percent mixed', 'c_percent white', 'c_percent christian',
#         'c_percent jewish', 'c_percent no religion', 'c_percent muslim',
#         'c_percent no central heating', 'c_percent wood heating',
#         'c_percent communal heating', 'c_percent TFW less than 2km',
#         'c_percent TFW 2km to 5km', 'c_percent TFW 60km and over',
#         'c_percent WFH', 'c_percent part-time',
#         'c_percent 15 hours or less worked',
#         'c_percent 49 or more hours worked', 'c_percent commute on foot',
#         'c_percent commute bus', 'c_percent commute bicycle', 'c_pop_density',
#         'geography', 'c_percent children up to 14', 'c_percent aged 65plus',
#         'c_percent married or in civil partnership', 'c_percent unemployed',
#         'c_percent very good health', 'c_percent bad health',
#         'c_percent poor-english', 'c_percent highly-deprived',
#         'c_percent mid-deprived', 'c_percent male', 'c_total population',
#         'o_diabetes_quantity_per_capita', 'o_opioids_quantity_per_capita',
#         'o_OME_per_capita', 'o_total_quantity_per_capita', 'e_NO2', 'e_ozone',
#         'e_total_aerosol_optical_depth_at_550nm_surface',
#         'e_particulate_matter_d_less_than_25_um_surface', 'e_ndvi'],
#        dtype='object'))

# %%
data.hist(figsize=(30,40), layout=(12,6));

# %%
# this can be removed once we add whole England, perhaps
# del data['c_urban area']

# %%
data.describe()
# Out:
#        c_percent asian  c_percent black  c_percent mixed  c_percent white  \
# count     17405.000000     17405.000000     17405.000000     17405.000000
# mean          0.077573         0.028404         0.024401         0.853402
# std           0.134624         0.055100         0.018270         0.189566
# min           0.000000         0.000000         0.000000         0.008043
# 25%           0.009609         0.002558         0.011391         0.820351
# 50%           0.024110         0.007602         0.018890         0.939541
# 75%           0.081317         0.025760         0.032421         0.970329
# max           0.962709         0.553134         0.164171         1.000000
#
#        c_percent christian  c_percent jewish  c_percent no religion  \
# count         17405.000000      17405.000000           17405.000000
# mean              0.480696          0.004187               0.373113
# std               0.103875          0.027655               0.103014
# min               0.005898          0.000000               0.002145
# 25%               0.425447          0.000000               0.324495
# 50%               0.490651          0.000644               0.383364
# 75%               0.550805          0.001724               0.440278
# max               0.819334          0.690909               0.692147
#
#        c_percent muslim  c_percent no central heating  c_percent wood heating  \
# count      17405.000000                  17405.000000            17405.000000
# mean           0.050714                      0.014141                0.001792
# std            0.111408                      0.010624                0.004761
# min            0.000000                      0.000000                0.000000
# 25%            0.003324                      0.006803                0.000000
# 50%            0.010563                      0.011598                0.000000
# 75%            0.039168                      0.018581                0.001506
# max            0.919977                      0.175159                0.074367
#
#        ...  c_total population  o_diabetes_quantity_per_capita  \
# count  ...        17405.000000                    17405.000000
# mean   ...         1674.952945                       40.274431
# std    ...          353.464153                       15.630737
# min    ...          999.000000                        0.019879
# 25%    ...         1437.000000                       32.955683
# 50%    ...         1606.000000                       42.495702
# 75%    ...         1843.000000                       50.341680
# max    ...         5746.000000                      104.837522
#
#        o_opioids_quantity_per_capita  o_OME_per_capita  \
# count                   17405.000000      17405.000000
# mean                       34.167270        513.321420
# std                        22.639406        592.167284
# min                         0.011755          0.095499
# 25%                        17.963569        194.086907
# 50%                        31.434121        349.953316
# 75%                        44.550878        594.565773
# max                       154.253629      10295.182768
#
#        o_total_quantity_per_capita         e_NO2       e_ozone  \
# count                 17405.000000  17405.000000  17405.000000
# mean                   1215.640714      0.000107    328.831661
# std                     494.335973      0.000018      1.130607
# min                       0.527588      0.000067    324.045296
# 25%                     966.365944      0.000095    328.076687
# 50%                    1269.282158      0.000105    329.193443
# 75%                    1527.474524      0.000117    329.429851
# max                    8458.757189      0.000162    330.423313
#
#        e_total_aerosol_optical_depth_at_550nm_surface  \
# count                                    17405.000000
# mean                                         0.128932
# std                                          0.006659
# min                                          0.109066
# 25%                                          0.124434
# 50%                                          0.128883
# 75%                                          0.134830
# max                                          0.146250
#
#        e_particulate_matter_d_less_than_25_um_surface        e_ndvi
# count                                    1.740500e+04  17383.000000
# mean                                     7.109381e-09      0.507913
# std                                      1.058992e-09      0.124404
# min                                      4.674161e-09     -0.168120
# 25%                                      6.508499e-09      0.431360
# 50%                                      6.754437e-09      0.509688
# 75%                                      7.844738e-09      0.595224
# max                                      1.621301e-08      0.821388
#
# [8 rows x 42 columns]

# %% [markdown]
# # Check data Correlations

# %% [markdown]
# ## Controls

# %%
controls = [c for c in data.columns if c.startswith('c_')]
predfeats = data[controls].copy()

fig, ax = plt.subplots(figsize=(44,44))         
corr = predfeats.corr(method='pearson')
heatmap = sns.heatmap(corr, annot=True , ax=ax ,cmap='coolwarm' , annot_kws={"fontsize":20}, vmin=-1, vmax=1 )
ax.set_xticklabels(corr.columns, fontsize=20 , rotation = 90)
ax.set_yticklabels(corr.columns, fontsize=20, rotation = 0)
cbar = heatmap.collections[0].colorbar
cbar.ax.tick_params(labelsize=20)

# Use tight_layout to adjust the padding between the subplots
# plt.tight_layout()

# fig.savefig('../res7s/correlogram_controls.png', dpi=300)

# %% [markdown]
# ## Environmental (i.e., our exogenous variables)

# %%
controls = [c for c in data.columns if c.startswith('e_')]
predfeats = data[controls].copy()

fig, ax = plt.subplots(figsize=(10,10))         
corr = predfeats.corr(method='pearson')
heatmap = sns.heatmap(corr, annot=True , ax=ax ,cmap='coolwarm' , annot_kws={"fontsize":20}, vmin=-1, vmax=1 )
ax.set_xticklabels(corr.columns, fontsize=20 , rotation = 90)
ax.set_yticklabels(corr.columns, fontsize=20, rotation = 0)
cbar = heatmap.collections[0].colorbar
cbar.ax.tick_params(labelsize=20)

# Use tight_layout to adjust the padding between the subplots
# plt.tight_layout()

# fig.savefig('../res7s/correlogram_environmental.png', dpi=300)

# %% [markdown]
# ## Outcomes

# %%
controls = [c for c in data.columns if c.startswith('o_')]
predfeats = data[controls].copy()

fig, ax = plt.subplots(figsize=(5,5))         
corr = predfeats.corr(method='pearson')
heatmap = sns.heatmap(corr, annot=True , ax=ax ,cmap='coolwarm' , annot_kws={"fontsize":20}, vmin=-1, vmax=1 )
ax.set_xticklabels(corr.columns, fontsize=20 , rotation = 90)
ax.set_yticklabels(corr.columns, fontsize=20, rotation = 0)
cbar = heatmap.collections[0].colorbar
cbar.ax.tick_params(labelsize=20)

# Use tight_layout to adjust the padding between the subplots
# plt.tight_layout()

# fig.savefig('../res7s/correlogram_outcomes.png', dpi=300)

# %% [markdown]
# ## Find and plot most correlated with prescriptions

# %% [markdown]
# ## Controls vs Outcomes

# %%
controls = [c for c in data.columns if (c.startswith('c_') or c.startswith('o_'))]
predfeats = data[controls].copy()

fig, ax = plt.subplots(figsize=(44,4))         
corr = predfeats.corr(method='pearson')

corr = corr[outcomes].T

heatmap = sns.heatmap(corr, annot=True , ax=ax ,cmap='coolwarm' , annot_kws={"fontsize":20}, vmin=-1, vmax=1 )
# ax.set_xticklabels(outcomes, fontsize=20 , rotation = 90)
# ax.set_yticklabels(corr.columns, fontsize=20, rotation = 0)
cbar = heatmap.collections[0].colorbar
cbar.ax.tick_params(labelsize=20)

# Use tight_layout to adjust the padding between the subplots
# plt.tight_layout()

# fig.savefig('../res7s/correlogram_controlsvsoutcomes.png', dpi=300)

# %% [markdown]
# ## Env vs Outcomes

# %%
controls = [c for c in data.columns if (c.startswith('e_') or c.startswith('o_'))]
predfeats = data[controls].copy()

fig, ax = plt.subplots(figsize=(10,3))         
corr = predfeats.corr(method='pearson')

corr = corr[outcomes].T

heatmap = sns.heatmap(corr, annot=True , ax=ax ,cmap='coolwarm' , annot_kws={"fontsize":20}, vmin=-1, vmax=1 )
# ax.set_xticklabels(outcomes, fontsize=20 , rotation = 90)
# ax.set_yticklabels(corr.columns, fontsize=20, rotation = 0)
cbar = heatmap.collections[0].colorbar
cbar.ax.tick_params(labelsize=20)

# Use tight_layout to adjust the padding between the subplots
# plt.tight_layout()

# fig.savefig('../res7s/correlogram_controlsvsoutcomes.png', dpi=300)

# %% [markdown]
# ## Below are some at first surpising links

# %%
c2 = 'o_opioids_quantity_per_capita'
c1 = 'e_NO2'
data.plot.scatter(x=c1, y=c2);
print ("Correlation is {}".format(data[[c1, c2]].\
                                  corr().values[0][-1]))
# Out:
# Correlation is -0.5136641290084646

# %%
c2 = 'o_opioids_quantity_per_capita'
c1 = 'e_total_aerosol_optical_depth_at_550nm_surface'
data.plot.scatter(x=c1, y=c2);
print ("Correlation is {}".format(data[[c1, c2]].\
                                  corr().values[0][-1]))
# Out:
# Correlation is -0.5252790650803947

# %%
c2 = 'o_opioids_quantity_per_capita'
c1 = 'e_total_aerosol_optical_depth_at_550nm_surface'
data.plot.scatter(x=c1, y=c2);
print ("Correlation is {}".format(data[[c1, c2]].\
                                  corr().values[0][-1]))
# Out:
# Correlation is -0.5252790650803947

# %%
c2 = 'o_opioids_quantity_per_capita'
c1 = 'e_particulate_matter_d_less_than_25_um_surface'
data.plot.scatter(x=c1, y=c2);
print ("Correlation is {}".format(data[[c1, c2]].\
                                  corr().values[0][-1]))
# Out:
# Correlation is -0.3333633893078975

# %% [markdown]
#  ## These suprising links are driven by the higher opioid prescriptions in rural areas

# %%
c2 = 'o_opioids_quantity_per_capita'
c1 = 'c_pop_density'
data.plot.scatter(x=c1, y=c2);
print ("Correlation is {}".format(data[[c1, c2]].\
                                  corr().values[0][-1]))
# Out:
# Correlation is -0.24312225079785987

# %% [markdown]
# # Define Data Inputs to the Models

# %%
controls = [c for c in data.columns if c.startswith("c_")]
environment = [c for c in data.columns if c.startswith("e_")]
outcomes = [c for c in data.columns if c.startswith("o_")]

features = controls + environment

# %%
outcome = 'o_diabetes_quantity_per_capita'

# %% [markdown]
# # VIF Colinearity

# %%
X = data[features].dropna()

# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
print(vif_data)
# Out:
#                                            feature          VIF
# 0                                  c_percent asian   124.357680
# 1                                  c_percent black    27.311622
# 2                                  c_percent mixed    16.792875
# 3                                  c_percent white  4995.122620
# 4                              c_percent christian   598.999978
# 5                                 c_percent jewish     2.942471
# 6                            c_percent no religion   439.129629
# 7                                 c_percent muslim     9.703955
# 8                     c_percent no central heating     4.946110
# 9                           c_percent wood heating     2.198530
# 10                      c_percent communal heating     1.303136
# 11                     c_percent TFW less than 2km    20.620993
# 12                        c_percent TFW 2km to 5km     8.181244
# 13                     c_percent TFW 60km and over     5.011955
# 14                                   c_percent WFH    45.213255
# 15                             c_percent part-time   225.632425
# 16               c_percent 15 hours or less worked    71.595456
# 17               c_percent 49 or more hours worked    27.292012
# 18                       c_percent commute on foot    22.282100
# 19                           c_percent commute bus     7.165901
# 20                       c_percent commute bicycle     3.535207
# 21                                   c_pop_density     5.256994
# 22                     c_percent children up to 14    76.287037
# 23                           c_percent aged 65plus    81.672838
# 24       c_percent married or in civil partnership   169.486572
# 25                            c_percent unemployed   167.966389
# 26                      c_percent very good health   461.325020
# 27                            c_percent bad health    37.980250
# 28                          c_percent poor-english     6.833668
# 29                       c_percent highly-deprived     2.291065
# 30                          c_percent mid-deprived    63.884758
# 31                                  c_percent male   907.567630
# 32                              c_total population    30.179458
# 33                                           e_NO2   129.752076
# 34                                         e_ozone  7449.326562
# 35  e_total_aerosol_optical_depth_at_550nm_surface  1507.069611
# 36  e_particulate_matter_d_less_than_25_um_surface   127.699433
# 37                                          e_ndvi    43.643757

# %% [markdown]
# # Functions

# %% [markdown]
# ## Random Forest with Feature Importance

# %%
"""
    https://towardsdatascience.com/random-forest-in-python-24d0893d51c0
"""

def feature_importance_default(rf, feature_list):
    
    print ('***************DEFAULT FEATURE IMPORTANCE**************')
    # Get numerical feature importances
    importances = list(rf.feature_importances_)
    # List of tuples with variable and importance
    feature_importances = [(feature, round(importance, 4)) \
                           for feature, importance in zip(feature_list, importances)]
    # Sort the feature importances by most important first
    feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
    # Print out the feature and importances 
    [print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
    
    # list of x locations for plotting
    x_values = list(range(len(importances)))
    # Make a bar chart
    plt.bar(x_values, importances, orientation = 'vertical')
    # Tick labels for x axis
    plt.xticks(x_values, feature_list, rotation='vertical')
    # Axis labels and title
    plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');  
    
    
    
def RF(features, outcome):
    # Labels are the values we want to predict
    labels = np.array(features[outcome])
    # Remove the labels from the features
    # axis 1 refers to the columns
    features= features.drop(outcomes, axis = 1)
    # Saving feature names for later use
    feature_list = list(features.columns)
    # Convert to numpy array
    features = np.array(features)
    
    # Split the data into training and testing sets
    train_features, test_features, train_labels, test_labels =\
            train_test_split(features, labels, test_size = 0.25, random_state = 42)
    
    print('Training Features Shape:', train_features.shape)
    print('Training Labels Shape:', train_labels.shape)
    print('Testing Features Shape:', test_features.shape)
    print('Testing Labels Shape:', test_labels.shape)
    
    

    # Instantiate model with 1000 decision trees
    rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
    # Train the model on training data
    rf.fit(train_features, train_labels);
    
    # Use the forest's predict method on the test data
    predictions = rf.predict(test_features)
    # Calculate the absolute errors
    errors = abs(predictions - test_labels)
    # Print out the mean absolute error (mae)
    print('Mean Absolute Error:', round(np.mean(errors), 2), '.')
    
# #     Calculate mean absolute percentage error (MAPE)
#     mape = 100 * (errors / test_labels)
# #     Calculate and display accuracy
#     accuracy = 100 - np.mean(mape)
#     print('Accuracy:', round(accuracy, 2), '%.')
    # 7s
#     mape = np.mean((abs(test_labels - predictions)/test_labels))*100
#     print('MAPE:', round(mape, 2), '%.')
#     accuracy = 100 - mape
#     print('Accuracy:', round(accuracy, 2), '%.')  
    
    # 7s 
    r2 = r2_score(test_labels, predictions)
    print('R2:', round(r2, 2), '.')
    
    feature_importance_default(rf, feature_list)

# %%
"""
    this is for an alternative, no the sklearn implementation, 
    of feature importance for a sanity check
"""
    
def feature_importance_v2(X, Y, names):
    """
        this is an alternative method to test from here
        http://blog.datadive.net/selecting-good-features-part-iii-random-forests/
        haven't tested it, yet. need to adapt the code
    """

    rf = RandomForestRegressor()
    scores = defaultdict(list)

    #crossvalidate the scores on a number of different random splits of the data
    for i, (train_idx, test_idx) in \
            enumerate(ShuffleSplit(n_splits=100, test_size=.3).split(X)):
        X_train, X_test = X[train_idx], X[test_idx]
        Y_train, Y_test = Y[train_idx], Y[test_idx]
        r = rf.fit(X_train, Y_train)
        acc = r2_score(Y_test, rf.predict(X_test))
        for i in range(X.shape[1]):
            X_t = X_test.copy()
            np.random.shuffle(X_t[:, i])
            shuff_acc = r2_score(Y_test, rf.predict(X_t))
            scores[names[i]].append((acc-shuff_acc)/acc)
    print ("Features sorted by their score:")
    print (sorted([(round(np.mean(score), 4), feat) for
                  feat, score in scores.items()], reverse=True))

#     %matplotlib inline
#     # Set the style
#     plt.style.use('fivethirtyeight')
#     # list of x locations for plotting
#     x_values = list(range(len(scores)))
#     # Make a bar chart
#     plt.bar(x_values, scores, orientation = 'vertical', color='#8f63f4')
#     # Tick labels for x axis
#     plt.xticks(x_values, feature_list, rotation='vertical')
#     # Axis labels and title
#     plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');  
    
    
def RF_v2(features, outcome):
    # Labels are the values we want to predict
    labels = np.array(features[outcome])
    # Remove the labels from the features
    # axis 1 refers to the columns
    features= features.drop(outcomes, axis = 1)
    # Saving feature names for later use
    feature_list = list(features.columns)
    # Convert to numpy array
    features = np.array(features)
    
   
    feature_importance_v2(features, labels, feature_list)

# %% [markdown]
# # Apply Models

# %% [markdown]
# ## Opioids

# %%
RF(features=data.set_index(['geography code','geography']).dropna(), \
   outcome='o_opioids_quantity_per_capita')
# Out:
# Training Features Shape: (13037, 38)
# Training Labels Shape: (13037,)
# Testing Features Shape: (4346, 38)
# Testing Labels Shape: (4346,)
# Mean Absolute Error: 7.84 .
# R2: 0.75 .
# ***************DEFAULT FEATURE IMPORTANCE**************
# Variable: e_total_aerosol_optical_depth_at_550nm_surface Importance: 0.3533
# Variable: c_percent white      Importance: 0.1216
# Variable: e_NO2                Importance: 0.0702
# Variable: c_percent WFH        Importance: 0.0628
# Variable: e_ozone              Importance: 0.0527
# Variable: c_percent bad health Importance: 0.0304
# Variable: c_percent commute bicycle Importance: 0.0236
# Variable: c_percent very good health Importance: 0.0215
# Variable: c_percent mixed      Importance: 0.0188
# Variable: c_percent TFW 2km to 5km Importance: 0.0162
# Variable: c_percent TFW 60km and over Importance: 0.0129
# Variable: c_percent christian  Importance: 0.0127
# Variable: c_percent TFW less than 2km Importance: 0.0117
# Variable: c_percent commute bus Importance: 0.0114
# Variable: c_percent 15 hours or less worked Importance: 0.0108
# Variable: e_ndvi               Importance: 0.0108
# Variable: c_percent 49 or more hours worked Importance: 0.0098
# Variable: c_percent asian      Importance: 0.0097
# Variable: c_percent black      Importance: 0.0093
# Variable: c_percent no religion Importance: 0.0093
# Variable: c_percent part-time  Importance: 0.0092
# Variable: c_percent children up to 14 Importance: 0.0087
# Variable: c_percent no central heating Importance: 0.0085
# Variable: c_pop_density        Importance: 0.0085
# Variable: c_percent male       Importance: 0.0084
# Variable: c_percent commute on foot Importance: 0.0083
# Variable: c_percent poor-english Importance: 0.0082
# Variable: c_total population   Importance: 0.0081
# Variable: c_percent muslim     Importance: 0.0079
# Variable: c_percent mid-deprived Importance: 0.0077
# Variable: c_percent married or in civil partnership Importance: 0.007
# Variable: c_percent aged 65plus Importance: 0.0067
# Variable: c_percent unemployed Importance: 0.0066
# Variable: c_percent jewish     Importance: 0.0054
# Variable: c_percent highly-deprived Importance: 0.0038
# Variable: c_percent wood heating Importance: 0.0037
# Variable: c_percent communal heating Importance: 0.0037
# Variable: e_particulate_matter_d_less_than_25_um_surface Importance: 0.0

# %%
RF_v2(features=data.set_index(['geography code','geography']).dropna(), \
   outcome='o_opioids_quantity_per_capita')
# Out:
# Features sorted by their score:
# [(0.5368, 'e_total_aerosol_optical_depth_at_550nm_surface'), (0.19, 'c_percent white'), (0.1578, 'e_ozone'), (0.1481, 'e_NO2'), (0.137, 'c_percent WFH'), (0.0436, 'c_percent bad health'), (0.0285, 'c_percent commute bicycle'), (0.0241, 'c_percent mixed'), (0.0178, 'c_percent very good health'), (0.013, 'c_percent TFW 2km to 5km'), (0.0112, 'c_percent christian'), (0.0091, 'c_percent commute bus'), (0.0077, 'c_percent 15 hours or less worked'), (0.0069, 'c_percent no religion'), (0.0069, 'c_percent TFW 60km and over'), (0.0063, 'c_percent asian'), (0.006, 'e_ndvi'), (0.0058, 'c_percent TFW less than 2km'), (0.0053, 'c_percent poor-english'), (0.005, 'c_percent part-time'), (0.0049, 'c_percent 49 or more hours worked'), (0.0044, 'c_percent muslim'), (0.0043, 'c_percent black'), (0.0037, 'c_percent children up to 14'), (0.0036, 'c_pop_density'), (0.0036, 'c_percent mid-deprived'), (0.0032, 'c_percent commute on foot'), (0.0028, 'c_percent aged 65plus'), (0.0024, 'c_percent male'), (0.0023, 'c_percent married or in civil partnership'), (0.0023, 'c_percent jewish'), (0.0022, 'c_total population'), (0.0022, 'c_percent no central heating'), (0.002, 'c_percent unemployed'), (0.0011, 'c_percent wood heating'), (0.0009, 'c_percent communal heating'), (0.0005, 'c_percent highly-deprived'), (0.0, 'e_particulate_matter_d_less_than_25_um_surface')]

# %%
RF(features=data.set_index(['geography code','geography']).dropna(), \
   outcome='o_OME_per_capita')
# Out:
# Training Features Shape: (13037, 38)
# Training Labels Shape: (13037,)
# Testing Features Shape: (4346, 38)
# Testing Labels Shape: (4346,)
# Mean Absolute Error: 284.48 .
# R2: 0.28 .
# ***************DEFAULT FEATURE IMPORTANCE**************
# Variable: c_percent white      Importance: 0.0707
# Variable: c_percent WFH        Importance: 0.0625
# Variable: e_NO2                Importance: 0.0611
# Variable: e_total_aerosol_optical_depth_at_550nm_surface Importance: 0.0569
# Variable: c_percent TFW 2km to 5km Importance: 0.0403
# Variable: c_percent mixed      Importance: 0.0349
# Variable: c_percent commute bicycle Importance: 0.0325
# Variable: c_total population   Importance: 0.0316
# Variable: e_ozone              Importance: 0.0287
# Variable: e_ndvi               Importance: 0.0286
# Variable: c_percent no central heating Importance: 0.0278
# Variable: c_percent muslim     Importance: 0.0265
# Variable: c_percent very good health Importance: 0.0262
# Variable: c_percent TFW 60km and over Importance: 0.0258
# Variable: c_percent part-time  Importance: 0.0256
# Variable: c_percent TFW less than 2km Importance: 0.0254
# Variable: c_percent 49 or more hours worked Importance: 0.0251
# Variable: c_percent asian      Importance: 0.0237
# Variable: c_percent 15 hours or less worked Importance: 0.0231
# Variable: c_percent commute on foot Importance: 0.023
# Variable: c_percent unemployed Importance: 0.0226
# Variable: c_percent commute bus Importance: 0.0225
# Variable: c_pop_density        Importance: 0.0225
# Variable: c_percent bad health Importance: 0.0213
# Variable: c_percent black      Importance: 0.021
# Variable: c_percent poor-english Importance: 0.02
# Variable: c_percent christian  Importance: 0.019
# Variable: c_percent male       Importance: 0.0187
# Variable: c_percent children up to 14 Importance: 0.0183
# Variable: c_percent jewish     Importance: 0.0182
# Variable: c_percent mid-deprived Importance: 0.018
# Variable: c_percent no religion Importance: 0.0165
# Variable: c_percent aged 65plus Importance: 0.0163
# Variable: c_percent married or in civil partnership Importance: 0.0146
# Variable: c_percent highly-deprived Importance: 0.0108
# Variable: c_percent wood heating Importance: 0.0099
# Variable: c_percent communal heating Importance: 0.0098
# Variable: e_particulate_matter_d_less_than_25_um_surface Importance: 0.0

# %%
RF_v2(features=data.set_index(['geography code','geography']).dropna(), \
   outcome='o_OME_per_capita')
# Out:
# Features sorted by their score:
# [(0.9419, 'c_percent white'), (0.7327, 'e_total_aerosol_optical_depth_at_550nm_surface'), (0.4802, 'c_percent WFH'), (0.4464, 'e_ozone'), (0.3924, 'e_NO2'), (0.2166, 'c_percent muslim'), (0.2003, 'c_percent mixed'), (0.135, 'c_percent asian'), (0.1277, 'c_percent very good health'), (0.1081, 'c_percent commute bicycle'), (0.0844, 'c_percent TFW 2km to 5km'), (0.0736, 'c_percent no central heating'), (0.0612, 'c_percent poor-english'), (0.0575, 'c_percent 49 or more hours worked'), (0.0482, 'e_ndvi'), (0.047, 'c_percent black'), (0.0464, 'c_percent bad health'), (0.0414, 'c_percent TFW less than 2km'), (0.0387, 'c_percent TFW 60km and over'), (0.0363, 'c_percent part-time'), (0.0359, 'c_percent commute on foot'), (0.0357, 'c_percent commute bus'), (0.0356, 'c_percent christian'), (0.0342, 'c_total population'), (0.0341, 'c_percent jewish'), (0.033, 'c_pop_density'), (0.0325, 'c_percent no religion'), (0.0287, 'c_percent 15 hours or less worked'), (0.0282, 'c_percent unemployed'), (0.0248, 'c_percent mid-deprived'), (0.02, 'c_percent aged 65plus'), (0.0199, 'c_percent married or in civil partnership'), (0.0162, 'c_percent male'), (0.0125, 'c_percent children up to 14'), (0.0077, 'c_percent highly-deprived'), (0.0058, 'c_percent communal heating'), (0.0056, 'c_percent wood heating'), (0.0, 'e_particulate_matter_d_less_than_25_um_surface')]

# %% [markdown]
# ## Diabetes

# %%
RF(features=data.set_index(['geography code','geography']).dropna(), \
   outcome='o_diabetes_quantity_per_capita')
# Out:
# Training Features Shape: (13037, 31)
# Training Labels Shape: (13037,)
# Testing Features Shape: (4346, 31)
# Testing Labels Shape: (4346,)
# Mean Absolute Error: 7.96 .
# Accuracy: -137.69 %.
# R2: 0.52 .
# *****************************
# Variable: c_percent WFH        Importance: 0.12
# Variable: c_percent commute bicycle Importance: 0.08
# Variable: e_NO2                Importance: 0.07
# Variable: c_percent christian  Importance: 0.05
# Variable: e_ozone              Importance: 0.05
# Variable: e_total_aerosol_optical_depth_at_550nm_surface Importance: 0.05
# Variable: c_percent white      Importance: 0.04
# Variable: c_percent TFW 2km to 5km Importance: 0.04
# Variable: c_percent married or in civil partnership Importance: 0.04
# Variable: c_percent asian      Importance: 0.03
# Variable: c_percent 49 or more hours worked Importance: 0.03
# Variable: c_percent commute bus Importance: 0.03
# Variable: c_percent very good health Importance: 0.03
# Variable: c_percent bad health Importance: 0.03
# Variable: c_percent jewish     Importance: 0.02
# Variable: c_percent no central heating Importance: 0.02
# Variable: c_percent TFW less than 2km Importance: 0.02
# Variable: c_percent TFW 60km and over Importance: 0.02
# Variable: c_percent part-time  Importance: 0.02
# Variable: c_percent 15 hours or less worked Importance: 0.02
# Variable: c_pop_density        Importance: 0.02
# Variable: c_percent children up to 14 Importance: 0.02
# Variable: c_percent aged 65plus Importance: 0.02
# Variable: c_percent unemployed Importance: 0.02
# Variable: c_percent poor-english Importance: 0.02
# Variable: c_percent male       Importance: 0.02
# Variable: c_total population   Importance: 0.02
# Variable: e_ndvi               Importance: 0.02
# Variable: c_percent communal heating Importance: 0.01
# Variable: c_percent highly-deprived Importance: 0.01
# Variable: e_particulate_matter_d_less_than_25_um_surface Importance: 0.0

# %%
RF_v2(features=data.set_index(['geography code','geography']).dropna(), \
   outcome='o_diabetes_quantity_per_capita')
# Out:
# Features sorted by their score:
# [(0.5877, 'c_percent WFH'), (0.2776, 'c_percent commute bicycle'), (0.2612, 'e_total_aerosol_optical_depth_at_550nm_surface'), (0.1953, 'e_NO2'), (0.1752, 'e_ozone'), (0.0635, 'c_percent TFW 2km to 5km'), (0.0618, 'c_percent mid-deprived'), (0.0579, 'c_percent christian'), (0.0561, 'c_percent very good health'), (0.0488, 'c_percent mixed'), (0.044, 'c_percent married or in civil partnership'), (0.0426, 'c_percent asian'), (0.039, 'c_percent white'), (0.0354, 'c_percent commute bus'), (0.0327, 'c_percent no religion'), (0.0258, 'c_percent bad health'), (0.0241, 'c_percent part-time'), (0.0233, 'c_percent 49 or more hours worked'), (0.0182, 'c_percent muslim'), (0.0174, 'c_percent jewish'), (0.015, 'c_percent TFW less than 2km'), (0.0149, 'c_percent commute on foot'), (0.0149, 'c_percent black'), (0.013, 'c_percent children up to 14'), (0.0127, 'c_percent TFW 60km and over'), (0.0123, 'c_pop_density'), (0.0117, 'c_percent aged 65plus'), (0.0114, 'c_percent poor-english'), (0.0111, 'e_ndvi'), (0.0093, 'c_percent male'), (0.0089, 'c_percent 15 hours or less worked'), (0.0077, 'c_percent no central heating'), (0.006, 'c_percent unemployed'), (0.0058, 'c_percent communal heating'), (0.0047, 'c_percent wood heating'), (0.0041, 'c_percent highly-deprived'), (0.0031, 'c_total population'), (0.0, 'e_particulate_matter_d_less_than_25_um_surface')]

# %% [markdown]
# # Total Prescriptions

# %%
RF(features=data.set_index(['geography code','geography']).dropna(), \
   outcome='o_total_quantity_per_capita')
# Out:
# Training Features Shape: (13037, 31)
# Training Labels Shape: (13037,)
# Testing Features Shape: (4346, 31)
# Testing Labels Shape: (4346,)
# Mean Absolute Error: 220.59 .
# Accuracy: -118.54 %.
# R2: 0.57 .
# *****************************
# Variable: e_total_aerosol_optical_depth_at_550nm_surface Importance: 0.12
# Variable: c_percent white      Importance: 0.11
# Variable: e_NO2                Importance: 0.11
# Variable: e_ozone              Importance: 0.07
# Variable: c_percent commute bicycle Importance: 0.05
# Variable: c_percent WFH        Importance: 0.04
# Variable: c_percent very good health Importance: 0.04
# Variable: c_percent christian  Importance: 0.03
# Variable: c_percent TFW 2km to 5km Importance: 0.03
# Variable: c_percent commute bus Importance: 0.03
# Variable: c_percent bad health Importance: 0.03
# Variable: c_percent asian      Importance: 0.02
# Variable: c_percent jewish     Importance: 0.02
# Variable: c_percent no central heating Importance: 0.02
# Variable: c_percent TFW less than 2km Importance: 0.02
# Variable: c_percent TFW 60km and over Importance: 0.02
# Variable: c_percent part-time  Importance: 0.02
# Variable: c_percent 15 hours or less worked Importance: 0.02
# Variable: c_percent 49 or more hours worked Importance: 0.02
# Variable: c_pop_density        Importance: 0.02
# Variable: c_percent children up to 14 Importance: 0.02
# Variable: c_percent aged 65plus Importance: 0.02
# Variable: c_percent married or in civil partnership Importance: 0.02
# Variable: c_percent unemployed Importance: 0.02
# Variable: c_percent poor-english Importance: 0.02
# Variable: c_percent male       Importance: 0.02
# Variable: c_total population   Importance: 0.02
# Variable: e_ndvi               Importance: 0.02
# Variable: c_percent communal heating Importance: 0.01
# Variable: c_percent highly-deprived Importance: 0.01
# Variable: e_particulate_matter_d_less_than_25_um_surface Importance: 0.0

# %%
RF_v2(features=data.set_index(['geography code','geography']).dropna(), \
   outcome='o_total_quantity_per_capita')
# Out:
# Features sorted by their score:
# [(0.4162, 'e_total_aerosol_optical_depth_at_550nm_surface'), (0.2569, 'e_ozone'), (0.2422, 'e_NO2'), (0.115, 'c_percent mixed'), (0.1139, 'c_percent WFH'), (0.1122, 'c_percent white'), (0.0837, 'c_percent commute bicycle'), (0.068, 'c_percent very good health'), (0.0572, 'c_percent bad health'), (0.0479, 'c_percent commute bus'), (0.032, 'c_percent TFW 2km to 5km'), (0.0232, 'c_percent christian'), (0.0173, 'c_percent black'), (0.016, 'c_percent muslim'), (0.0149, 'c_percent jewish'), (0.0147, 'c_percent mid-deprived'), (0.0131, 'c_percent asian'), (0.0131, 'c_percent TFW 60km and over'), (0.0123, 'c_percent TFW less than 2km'), (0.012, 'e_ndvi'), (0.0116, 'c_percent no religion'), (0.0114, 'c_percent 49 or more hours worked'), (0.0108, 'c_percent poor-english'), (0.0108, 'c_percent part-time'), (0.0099, 'c_percent children up to 14'), (0.0099, 'c_percent 15 hours or less worked'), (0.0098, 'c_percent married or in civil partnership'), (0.0081, 'c_percent aged 65plus'), (0.0073, 'c_percent commute on foot'), (0.0072, 'c_percent unemployed'), (0.0061, 'c_pop_density'), (0.005, 'c_percent male'), (0.0049, 'c_percent no central heating'), (0.0042, 'c_total population'), (0.0035, 'c_percent wood heating'), (0.0026, 'c_percent highly-deprived'), (0.0025, 'c_percent communal heating'), (0.0, 'e_particulate_matter_d_less_than_25_um_surface')]
